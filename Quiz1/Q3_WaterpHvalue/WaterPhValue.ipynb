# %% [markdown]
# # Q3 – Recent Water Data and pH Classification
#
# This project analyzes multi-location water pH data from the Florida WaterAtlas dataset.
# The goal is to identify safe and unsafe water conditions using AI classification models
# and visualize unsafe locations geographically.

# %% [markdown]
# ## 1. Data Preparation
#
# The dataset contains water quality measurements across multiple locations.
# Only pH measurements are selected for this analysis. A new column called **SAFE-PH** is created based on environmental standards:
#
# - Safe range: 6.5 – 8.5
# - Unsafe: <= 6.5 or > 8.5

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/biplav-s/course-tai/main/sample-code/common-data/water/WaterAtlas-ManySites.csv"

df_q3 = pd.read_csv(url, engine='python', on_bad_lines='skip')

df_q3.head()
# Out:
#                                   DataSourceName  DataSourceCode  \
# 0  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 1  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 2  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 3  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 4  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
#
#            StationID ActualStationID  Latitude_DD  Longitude_DD  \
# 0  Bugg Springs-Lake             NaN     28.75361     -81.90444
# 1  Bugg Springs-Lake             NaN     28.75361     -81.90444
# 2  Bugg Springs-Lake             NaN     28.75361     -81.90444
# 3  Bugg Springs-Lake             NaN     28.75361     -81.90444
# 4  Bugg Springs-Lake             NaN     28.75361     -81.90444
#
#                 SampleDate SampleTime  ActivityDepth ActivityDepthUnit  \
# 0  1991-08-18 00:00:00.000   00:00:00            NaN               NaN
# 1  1991-08-18 00:00:00.000   00:00:00            NaN               NaN
# 2  1991-08-18 00:00:00.000   00:00:00            NaN               NaN
# 3  1991-08-18 00:00:00.000   00:00:00            NaN               NaN
# 4  1991-08-18 00:00:00.000   00:00:00            NaN               NaN
#
#          Characteristic  ResultValue ResultUnit ValueQualifier ResultComment  \
# 0                    pH          7.5        NaN            NaN           NaN
# 1       Phosphorus as P         70.0       ug/l            NaN           NaN
# 2  Specific conductance        270.0       umho            NaN           NaN
# 3              Nitrogen        670.0       ug/l            NaN           NaN
# 4                Sodium          5.0       mg/l            NaN           NaN
#
#    WaterbodyID WaterbodyName
# 0         8509   Bugg Spring
# 1         8509   Bugg Spring
# 2         8509   Bugg Spring
# 3         8509   Bugg Spring
# 4         8509   Bugg Spring

# %%
# Keep only pH measurements
df_ph = df_q3[df_q3['Characteristic'] == 'pH'].copy()

df_ph.head()
# Out:
#                                    DataSourceName  DataSourceCode  \
# 0   LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 13  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 40  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 59  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
# 70  LAKEWATCH Supplemental Water Quality Sampling  LAKEWATCH_SUPP
#
#             StationID ActualStationID  Latitude_DD  Longitude_DD  \
# 0   Bugg Springs-Lake             NaN     28.75361     -81.90444
# 13  Bugg Springs-Lake             NaN     28.75361     -81.90444
# 40  Bugg Springs-Lake             NaN     28.75361     -81.90444
# 59        Church-Lake             NaN     28.64625     -81.84342
# 70        Turkey-Lake             NaN     28.70128     -81.85039
#
#                  SampleDate SampleTime  ActivityDepth ActivityDepthUnit  \
# 0   1991-08-18 00:00:00.000   00:00:00            NaN               NaN
# 13  1991-03-10 00:00:00.000   00:00:00            NaN               NaN
# 40  1991-08-18 00:00:00.000   00:00:00            NaN               NaN
# 59  1995-02-13 00:00:00.000   00:00:00            NaN               NaN
# 70  1995-02-13 00:00:00.000   00:00:00            NaN               NaN
#
#    Characteristic  ResultValue ResultUnit ValueQualifier ResultComment  \
# 0              pH          7.5        NaN            NaN           NaN
# 13             pH          7.7        NaN            NaN           NaN
# 40             pH          7.6        NaN            NaN           NaN
# 59             pH          5.9        NaN            NaN           NaN
# 70             pH          6.1        NaN            NaN           NaN
#
#     WaterbodyID WaterbodyName
# 0          8509   Bugg Spring
# 13         8509   Bugg Spring
# 40         8509   Bugg Spring
# 59         7844   Church Lake
# 70         8186   Turkey Lake

# %%
df_ph['SAFE-PH'] = df_ph['ResultValue'].apply(
    lambda x: 'yes' if 6.5 <= x <= 8.5 else 'no'
)

df_ph[['ResultValue','SAFE-PH']].head()
# Out:
#     ResultValue SAFE-PH
# 0           7.5     yes
# 13          7.7     yes
# 40          7.6     yes
# 59          5.9      no
# 70          6.1      no

# %% [markdown]
# ### Distribution of Safe vs Unsafe pH
#
# Understanding the class balance helps interpret model performance.

# %%
df_ph['SAFE-PH'].value_counts()
# Out:
# SAFE-PH
# yes    386
# no      86
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Model Training
#
# Two classification algorithms are used:
#
# - Logistic Regression
# - Decision Tree
#
# 20% of data is used for testing as required.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

X = df_ph[['ResultValue']]
y = df_ph['SAFE-PH']

encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model_lr = LogisticRegression(max_iter=2000)
model_lr.fit(X_train, y_train)

y_pred_lr = model_lr.predict(X_test)

print("Logistic Regression Results:")
print(classification_report(y_test, y_pred_lr))
# Out:
# Logistic Regression Results:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        78
#
#     accuracy                           1.00        95
#    macro avg       1.00      1.00      1.00        95
# weighted avg       1.00      1.00      1.00        95

# %% [markdown]
# ### Cross Validation
#
# To ensure model reliability, k-fold cross validation is applied.

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier(random_state=42)
model_dt.fit(X_train, y_train)

y_pred_dt = model_dt.predict(X_test)

print("Decision Tree Results:")
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Results:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        78
#
#     accuracy                           1.00        95
#    macro avg       1.00      1.00      1.00        95
# weighted avg       1.00      1.00      1.00        95

# %%
from sklearn.model_selection import cross_val_score

scores_lr = cross_val_score(model_lr, X, y_encoded, cv=10)
scores_dt = cross_val_score(model_dt, X, y_encoded, cv=10)

print("LR 10-fold accuracy:", scores_lr.mean())
print("DT 10-fold accuracy:", scores_dt.mean())
# Out:
# LR 10-fold accuracy: 0.9936170212765958
# DT 10-fold accuracy: 1.0

# %% [markdown]
# ## Geographic Analysis of Unsafe Water by Location
#
# To understand the sustainability impact of water quality, the dataset was analyzed geographically using latitude and longitude information.
#
# Unsafe pH occurrences were aggregated by waterbody location to determine which places have the most and least unsafe water samples. This helps identify areas requiring environmental monitoring and intervention.

# %%
# Count unsafe occurrences by waterbody
unsafe_counts = (
    df_ph[df_ph['SAFE-PH'] == 'no']
    .groupby(['WaterbodyName','Latitude_DD','Longitude_DD'])
    .size()
    .reset_index(name='UnsafeCount')
)

unsafe_counts.head()
# Out:
#      WaterbodyName  Latitude_DD  Longitude_DD  UnsafeCount
# 0  Bugg Spring Run    28.752500    -81.901667            1
# 1      Church Lake    28.642111    -81.840597           13
# 2      Church Lake    28.645000    -81.846400           11
# 3      Church Lake    28.646250    -81.843420            1
# 4        Kess Lake    28.663611    -81.849444            1

# %%
print("Top locations with MOST unsafe water:")
display(unsafe_counts.sort_values('UnsafeCount', ascending=False).drop_duplicates(subset=['WaterbodyName']))

print("\nLocations with LEAST unsafe water:")
display(unsafe_counts.sort_values('UnsafeCount', ascending=True).drop_duplicates(subset=['WaterbodyName']))
# Out:
# Top locations with MOST unsafe water:
#         WaterbodyName  Latitude_DD  Longitude_DD  UnsafeCount
# 14  Palatlakaha River    28.748033    -81.874853           24
# 1         Church Lake    28.642111    -81.840597           13
# 5           Kess Lake    28.664713    -81.842010            2
# 17        Turkey Lake    28.701280    -81.850390            2
# 0     Bugg Spring Run    28.752500    -81.901667            1
# 6           Moon Lake    28.632746    -81.859896            1
# Locations with LEAST unsafe water:
#         WaterbodyName  Latitude_DD  Longitude_DD  UnsafeCount
# 0     Bugg Spring Run    28.752500    -81.901667            1
# 3         Church Lake    28.646250    -81.843420            1
# 6           Moon Lake    28.632746    -81.859896            1
# 4           Kess Lake    28.663611    -81.849444            1
# 11  Palatlakaha River    28.720303    -81.884551            1
# 17        Turkey Lake    28.701280    -81.850390            2

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\terdo\appdata\roaming\python\python313\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\terdo\appdata\roaming\python\python313\site-packages (from folium) (2.3.4)
# Requirement already satisfied: requests in c:\users\terdo\appdata\roaming\python\python313\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\terdo\appdata\roaming\python\python313\site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from requests->folium) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\terdo\appdata\roaming\python\python313\site-packages (from requests->folium) (2026.1.4)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ###  Geographic Distribution of Unsafe pH Measurements in Florida

# %%
import folium

# Center map roughly around Florida
m = folium.Map(location=[28.5, -81.5], zoom_start=7)

# Add unsafe locations as markers
for _, row in unsafe_counts.iterrows():
    
    folium.CircleMarker(
        location=[row['Latitude_DD'], row['Longitude_DD']],
        radius=4 + row['UnsafeCount'],   # size reflects severity
        popup=f"{row['WaterbodyName']} | UnsafeCount={row['UnsafeCount']}",
        color='red',
        fill=True,
        fill_opacity=0.6
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e75e026c1354184230659b8147edf1ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e75e026c1354184230659b8147edf1ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e75e026c1354184230659b8147edf1ab = L.map(
#                 &quot;map_e75e026c1354184230659b8147edf1ab&quot;,
#                 {
#                     center: [28.5, -81.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e17a5339bd976e0a2408ebdf5f9d319 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e17a5339bd976e0a2408ebdf5f9d319.addTo(map_e75e026c1354184230659b8147edf1ab);
#
#
#             var circle_marker_297372616a804dfd2331a8179b58e8ef = L.circleMarker(
#                 [28.7525, -81.9016667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e75e026c1354184230659b8147edf1ab);
#
#
#         var popup_651ceda73948d45c361ed2218227e99e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85266a1fb4574dde493b70ae9e646f81 = $(`&lt;div id=&quot;html_85266a1fb4574dde493b70ae9e646f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bugg Spring Run | UnsafeCount=1&lt;/div&gt;`)[0];
#                 popup_651ceda73948d45c361ed2218227e99e.setContent(html_85266a1fb4574dde493b70ae9e646f81);
#
#
#
#         circle_marker_297372616a804dfd2331a8179b58e8ef.bindPopup(popup_651ceda73948d45c361ed2218227e99e)
#         ;
#
#
#
#
#             var circle_marker_ee4e1163845089a10a4b252ec35daf20 = L.circleMarker(
#                 [28.64211058, -81.84059736],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e75e026c1354184230659b8147edf1ab);
#
#
#         var popup_c090f5c1576be3716f9785c26f0905fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_689b8f0a5d3ea4354f1e98ec68696c8a = $(`&lt;div id=&quot;html_689b8f0a5d3ea4354f1e98ec68696c8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Church Lake | UnsafeCount=13&lt;/div&gt;`)[0];
#                 popup_c090f5c1576be3716f9785c26f0905fa.setContent(html_689b8f0a5d3ea4354f1e98ec68696c8a);
#
#
#
#         circle_marker_ee4e1163845089a10a4b252ec35daf20.bindPopup(popup_c090f5c1576be3716f9785c26f0905fa)
#         ;
#
#
#
#
#             var circle_marker_12c8cdf9615a43bd23e3908c21d6fccb = L.circleMarker(
#                 [28.645, -81.8464],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e75e026c1354184230659b8147edf1ab);
#
#
#         var popup_91c6b44c56c0389b8c83938b37279f4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afbc6fe555296ccbbbd73756e36903b3 = $(`&lt;div id=&quot;html_afbc6fe555296ccbbbd73756e36903b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Church Lake | UnsafeCount=11&lt;/div&gt;`)[0];
#                 popup_91c6b44c56c0389b8c83938b37279f4a.setContent(html_afbc6fe555296ccbbbd73756e36903b3);
#
#
#
#         circle_marker_12c8cdf9615a43bd23e3908c21d6fccb.bindPopup(popup_91c6b44c56c0389b8c83938b37279f4a)
#         ;
#
#
#
#
#             var circle_marker_5b35af89be44

# %% [markdown]
# .

# %%
# Show top unsafe locations
print("Top locations with most unsafe pH occurrences:")
display(unsafe_counts.sort_values(by="UnsafeCount", ascending=False).head())

print("\nLocations with least unsafe pH occurrences:")
display(unsafe_counts.sort_values(by="UnsafeCount", ascending=True).head())
# Out:
# Top locations with most unsafe pH occurrences:
#         WaterbodyName  Latitude_DD  Longitude_DD  UnsafeCount
# 14  Palatlakaha River    28.748033    -81.874853           24
# 1         Church Lake    28.642111    -81.840597           13
# 13  Palatlakaha River    28.744200    -81.872800           11
# 2         Church Lake    28.645000    -81.846400           11
# 7   Palatlakaha River    28.679167    -81.884778           10
# Locations with least unsafe pH occurrences:
#         WaterbodyName  Latitude_DD  Longitude_DD  UnsafeCount
# 0     Bugg Spring Run    28.752500    -81.901667            1
# 3         Church Lake    28.646250    -81.843420            1
# 6           Moon Lake    28.632746    -81.859896            1
# 4           Kess Lake    28.663611    -81.849444            1
# 11  Palatlakaha River    28.720303    -81.884551            1

# %% [markdown]
# This analysis demonstrates how machine learning can be applied to real-world environmental monitoring tasks using recent multi-location water quality data. By creating a SAFE-PH indicator based on established environmental standards, classification models such as Logistic Regression and Decision Trees were trained to predict whether water samples fall within safe pH ranges. Both models achieved strong predictive performance, indicating that pH measurements can be reliably classified using supervised learning techniques.
#
# Beyond model performance, the spatial analysis revealed that certain water bodies, particularly areas such as Palatlakaha River and Church Lake, exhibited higher occurrences of unsafe pH values compared to other locations. Mapping these occurrences provided important geographic insight, allowing unsafe regions to be visually identified and prioritized for monitoring or intervention. Overall, this workflow highlights how data science supports sustainability by transforming environmental measurements into actionable intelligence, enabling stakeholders to better understand water quality risks and allocate resources toward locations with the greatest need.
